# %% [markdown]
# <h1> Practice project </h1>
#
# - drawing a USA map in matplotlib
# - projects in this coruse will be a lot about plotting cancer-risk data on county-level in US
# - pygal for class X matplotlib for projects
# - 4 practice projects
# - this time it is: Draw a county-level map of the USA in matplotlib
# - SVG is good bcs it is based on coordinates --> can be reproduced and analyzed more easily
# - they provided PNG as well bcs matplotlib allegedly doesnt support SVG
#     - but will draw these PNGs
# - pyplot is a module in matplotlib (https://matplotlib.org/2.0.2/api/pyplot_api.html)
# - so review it + add the matplotlib based code to the provided template ...
# - ... and draw the PNG version of the US map
# - (they use pyplot methods like imread, imshow, show ...)

# %% [markdown]
# <h3> After project reflextion </h3>
#
# - it is cool module (even though I have seen like 0.0005 % of it)
# - it seems like it uses logic that it stacks stuff over itself
# - until you tell it to show it and start stacking again
# - if I havent told it, it would stack everything
# - also .shape method is built-in even in basic Python(!) --> works for tuples etc
# - map is good for plotting too if we know the dimensions --> we can treat it like a map then ... duh

# %%
import matplotlib

# %%
"""
Week 1 practice project template for Python Data Visualization
Load a county-level PNG map of the USA and draw it using matplotlib
"""

import matplotlib.pyplot as plt

# Houston location

USA_SVG_SIZE = [555, 352]
HOUSTON_POS = [302, 280]


def draw_USA_map(map_name):
    """
    Given the name of a PNG map of the USA (specified as a string),
    draw this map using matplotlib
    """
     
    # Load map image, note that using 'rb'option in open() is critical since png files are binary
    image_data = plt.imread(map_name)
    #  Get dimensions of USA map image
    ypixels, xpixels, bands = image_data.shape
    # Plot USA map
    plt.imshow(image_data)
    # Plot green scatter point in center of map
    plt.scatter([xpixels/2], [ypixels/2], c="g") 
    # Plot red scatter point on Houston, Tx - include code that rescale coordinates for larger PNG files
    plt.scatter(HOUSTON_POS[0] * (xpixels/USA_SVG_SIZE[0]), HOUSTON_POS[1] * (ypixels/USA_SVG_SIZE[1]), c="r")
    plt.show()

draw_USA_map("USA_Counties_555x352.png")
draw_USA_map("USA_Counties_1000x634.png")
